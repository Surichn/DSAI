# %% [markdown]
# <a href="https://colab.research.google.com/github/Surichn/DSAI/blob/main/DS/TA/NLP/NLP_Tran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Transformers

# %%
# !pip install datasets transformers[sentencepiece]
# Out:
# ...
#      |████████████████████████████████| 312 kB 13.8 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 42.8 MB/s
# ...
#      |████████████████████████████████| 212 kB 65.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 59.3 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 134 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 127 kB 56.9 MB/s
# ...
#      |████████████████████████████████| 94 kB 486 kB/s
# ...
#      |████████████████████████████████| 144 kB 37.6 MB/s
# ...
#      |████████████████████████████████| 271 kB 52.1 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 41.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 25.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 49.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 56.0 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("All is well")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998294115066528}]

# %%
classifier("I am not in a mood to study today")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9992809891700745}]

# %% [markdown]
# Zero shot classifiation

# %%
classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# {'labels': ['education', 'business', 'politics'],
#  'scores': [0.7425564527511597, 0.18465934693813324, 0.07278425991535187],
#  'sequence': 'This is a course about Transformers'}

# %%
sequence = "Profit margin is above the industry average"
candidate_labels =["education","politics","business"]     

classifier(sequence,candidate_labels)
# Out:
# {'labels': ['business', 'education', 'politics'],
#  'scores': [0.9107903838157654, 0.06119620054960251, 0.028013434261083603],
#  'sequence': 'Profit margin is above the industry average'}

# %% [markdown]
# Text Generation

# %%
generator = pipeline("text-generation")

generator("In today's meeting let us discuss about")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "In today's meeting let us discuss about the nature of our shared knowledge and how we might deal with those issues.\n\nQ: And before that, what will you tell us about our past?\n\nH. BRIAN: We are"}]
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "In today's meeting let us discuss about the most basic and common problems of our times:\n\nAwareness of the financial crisis (in short, the economic crises created by capitalism) is a problem that has been going on for some time now"}]
